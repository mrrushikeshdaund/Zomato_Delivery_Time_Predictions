# %% [markdown]
# ## Zomato Delivery Time Predictions
#
# ##### Introduction About the Data : The dataset The goal is to predict Delivery time of given Zomato (Regression Analysis).

# %%
import pandas as pd

# %%
df = pd.read_csv("data/Zomato_Delivery_Dataset.csv")
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# ...

# %%
df = df.drop(labels=['ID','Delivery_person_ID'],axis=1)

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 0                 36.0                      4.2            30.327968  \
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude
# 0             78.046106                   30.397968  \
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# 0                    78.116106  12-02-2022       21:55             22:10  \
# 1                    76.347589  13-02-2022       14:55             15:05
# ...

# %%
df.isnull().sum()
# Out:
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
df['Delivery_person_Age'] = df['Delivery_person_Age'].fillna(value=df['Delivery_person_Age'].mean())

# %%
df['Delivery_person_Ratings'] = df['Delivery_person_Ratings'].fillna(value=str(df['Delivery_person_Ratings'].mode()))

# %%
df['Time_Orderd'] = df['Time_Orderd'].fillna(value=str(df['Time_Orderd'].mode()))

# %%
df['Weather_conditions'] = df['Weather_conditions'].fillna(value=str(df['Weather_conditions'].mode()))

# %%
df['Road_traffic_density'] = df['Road_traffic_density'].fillna(value=str(df['Road_traffic_density'].mode()))

# %%
df['multiple_deliveries'] = df['multiple_deliveries'].fillna(value=int(0))

# %%
df['Festival'] = df['Festival'].fillna(value=str(df['Festival'].mode()))

# %%
df['City'] = df['City'].fillna(value=str(df['City'].mode()))

# %%
df.isnull().sum()
# Out:
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weather_conditions             0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken (min)               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          45584 non-null  float64
#  1   Delivery_person_Ratings      45584 non-null  object
#  2   Restaurant_latitude          45584 non-null  float64
#  3   Restaurant_longitude         45584 non-null  float64
#  4   Delivery_location_latitude   45584 non-null  float64
#  5   Delivery_location_longitude  45584 non-null  float64
#  6   Order_Date                   45584 non-null  object
#  7   Time_Orderd                  45584 non-null  object
#  8   Time_Order_picked            45584 non-null  object
#  9   Weather_conditions           45584 non-null  object
#  10  Road_traffic_density         45584 non-null  object
#  11  Vehicle_condition            45584 non-null  int64
# ...

# %%
df.head()
# Out:
#    Delivery_person_Age Delivery_person_Ratings  Restaurant_latitude
# 0                 36.0                     4.2            30.327968  \
# 1                 21.0                     4.7            10.003064
# 2                 23.0                     4.7            18.562450
# 3                 34.0                     4.3            30.899584
# 4                 24.0                     4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude
# 0             78.046106                   30.397968  \
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# 0                    78.116106  12-02-2022       21:55             22:10  \
# 1                    76.347589  13-02-2022       14:55             15:05
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
numerical_columns = df.columns[df.dtypes!='object']
categorical_columns = df.columns[df.dtypes=='object']
print("Numerical Columns :- ",numerical_columns)
print("Categorical Columns :- ",categorical_columns)
# Out:
# Numerical Columns :-  Index(['Delivery_person_Age', 'Restaurant_latitude', 'Restaurant_longitude',
#        'Delivery_location_latitude', 'Delivery_location_longitude',
#        'Vehicle_condition', 'multiple_deliveries', 'Time_taken (min)'],
#       dtype='object')
# Categorical Columns :-  Index(['Delivery_person_Ratings', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Type_of_order', 'Type_of_vehicle', 'Festival', 'City'],
#       dtype='object')

# %%
df[categorical_columns].describe()
# Out:
#         Delivery_person_Ratings  Order_Date
# count                   45584.0       45584  \
# unique                     29.0          44
# top                         4.8  15-03-2022
# freq                     7146.0        1192
#
#                                          Time_Orderd Time_Order_picked
# count                                          45584             45584  \
# unique                                           177               193
# top     0    21:55\nName: Time_Orderd, dtype: object             21:30
# freq                                            1731               495
#
#        Weather_conditions Road_traffic_density Type_of_order Type_of_vehicle
# count               45584                45584         45584           45584  \
# unique                  7                    5             4               4
# top                   Fog                  Low         Snack      motorcycle
# ...

# %%
df[numerical_columns].describe()
# Out:
#        Delivery_person_Age  Restaurant_latitude  Restaurant_longitude
# count         45584.000000         45584.000000          45584.000000  \
# mean             29.566911            17.017948             70.229684
# std               5.695578             8.185674             22.885575
# min              15.000000           -30.905562            -88.366217
# 25%              25.000000            12.933284             73.170000
# 50%              29.566911            18.551440             75.897963
# 75%              34.000000            22.728163             78.044095
# max              50.000000            30.914057             88.433452
#
#        Delivery_location_latitude  Delivery_location_longitude
# count                45584.000000                 45584.000000  \
# mean                    17.465480                    70.844161
# std                      7.335562                    21.120578
# min                      0.010000                     0.010000
# ...
